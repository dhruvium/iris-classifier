# %% [markdown]
# # **Simple Iris Classification Model**

# %% [markdown]
# Let's start by importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Now lets load the dataset

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Now lets try to visualize the dataset

# %%
sns.pairplot(df)

# %% [markdown]
# Now let seperate input columns and output columns

# %%
data = df.values

X = data[:,0:4]
Y = data[:,4]

# %% [markdown]
# Now lets split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,Y, test_size=0.2)

# %% [markdown]
# Now lets use the support vector machine algorithm

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(Xtrain, ytrain)

SVC()
# Out:
# SVC()

# %%
prediction = model.predict(Xtest)

# %% [markdown]
# Now we will calculate the accuracy of the model

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(ytest, prediction))
# Out:
# 0.9666666666666667

# %% [markdown]
# Now lets try to enter a new flower data and try to predict it with our model

# %%
new_flower_data = np.array([[5.0, 3.5, 1.4, 0.2]])

predicted_species = model.predict(new_flower_data)

print(f"The predicted species for the new flower is: {predicted_species[0]}")
# Out:
# The predicted species for the new flower is: setosa
